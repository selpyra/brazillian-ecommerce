# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset

# %% [markdown]
# - **Nama:** Selpyra Febrianty
# - **Email:** selpyra.f@gmail.com
# - **ID Dicoding:** selpyra

# %% [markdown]
# # Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1
# - Pertanyaan 2

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
orders_df = pd.read_csv('orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
customers_df = pd.read_csv('customers_dataset.csv')
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
productse_df = pd.read_csv('products_dataset.csv')
productse_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
orders_items_df = pd.read_csv('order_items_dataset.csv')
orders_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Menilai tabel `orders_df`

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
orders_df.nunique()
# Out:
# order_id                         99441
# customer_id                      99441
# order_status                         8
# order_purchase_timestamp         98875
# order_approved_at                90733
# order_delivered_carrier_date     81018
# order_delivered_customer_date    95664
# order_estimated_delivery_date      459
# dtype: int64

# %%
print('Jumlah Duplikasi data: ', orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah Duplikasi data:  0
#             order_purchase_timestamp              order_approved_at  \
# count                          99441                          99281
# mean   2017-12-31 08:43:12.776581120  2017-12-31 18:35:24.098800128
# min              2016-09-04 21:15:19            2016-09-15 12:16:38
# 25%              2017-09-12 14:46:19            2017-09-12 23:24:16
# 50%              2018-01-18 23:04:36            2018-01-19 11:36:13
# 75%              2018-05-04 15:42:16            2018-05-04 20:35:10
# max              2018-10-17 17:30:18            2018-09-03 17:40:06
#
#         order_delivered_carrier_date  order_delivered_customer_date  \
# count                          97658                          96476
# mean   2018-01-04 21:49:48.138278656  2018-01-14 12:09:19.035542272
# min              2016-10-08 10:34:01            2016-10-11 13:46:32
# 25%    2017-09-15 22:28:50.249999872  2017-09-25 22:07:22.249999872
# ...

# %% [markdown]
# Menilai tabel `customers_df`

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
print('Jumlah duplikasi data: ', customers_df.duplicated().sum())
customers_df.describe()
# Out:
# Jumlah duplikasi data:  0
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# Menilai tabel `productse_df`

# %%
productse_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
print('Jumlah duplikasi data: ', productse_df.duplicated().sum())
productse_df.describe()
# Out:
# Jumlah duplikasi data:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# Menilai tabel `order_items_df`

# %%
orders_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
orders_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print('Jumlah duplikasi data: ', orders_items_df.duplicated().sum())
orders_items_df.describe()
# Out:
# Jumlah duplikasi data:  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Membersihkan tabel `orders_df`

# %% [markdown]
# Duplicate data

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# Memperbaiki tipe data

# %%
datetime_columns = ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore `customers_df`

# %%
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 32835  8604d93017eead9cf30eab424c9adbce  868df2e96f28e3a3d98f7044306270cc
# 88680  3dc77678850c657617eda579624570e2  8562cb7be6bb8698157e2d6522247f47
# 46733  b115d8f301378d8b3942697d6c134fc3  d9c71c881802a7ac4d34619f175e68ce
# 13267  748dc3cf89539712218c89009f5db25e  2ecbae05cce0ccdb6bd7576f223e6f2c
# 94255  3f45162d0e6bf5444b4ccfac3bde919e  3e214f1c2a595ca923e28695c19cee01
#
#        customer_zip_code_prefix   customer_city customer_state
# 32835                     22221  rio de janeiro             RJ
# 88680                     71693        brasilia             DF
# 46733                     18520       cerquilho             SP
# 13267                     29215       guarapari             ES
# 94255                      3707       sao paulo             SP

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers_df.customer_id.is_unique
# Out:
# True

# %%
customers_df.customer_id.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99436    False
# 99437    False
# 99438    False
# 99439    False
# 99440    False
# Name: customer_id, Length: 99441, dtype: bool

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Explore `orders_df`

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 60289  bc10788436288a29d001a6ec0e76f677  dc4158ce77a389b5672ae596ee0da730
# 13937  e80816e94dec73e777b4951533d8f50c  6a22bc47f4e4d19f68ea3691bc6a49fe
# 3965   51ceba3ba51d4b4543e7f78e181e0ba9  e7659c6f9fc78ba546ee2b0615258589
# 30651  d1a6ee88427645deee3a642c9f27e39a  454b4ee87a1b006a8c8b46203d670790
# 14787  6f51907687d51529d5d0a147cf761f0c  db2cd76dfa613aae8ec025a8bda2b3e3
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 60289    delivered      2018-01-15 22:32:45 2018-01-16 13:55:31
# 13937    delivered      2018-01-11 07:36:59 2018-01-12 03:32:29
# 3965     delivered      2017-01-23 13:31:26 2017-01-23 13:45:18
# 30651    delivered      2018-08-01 19:52:37 2018-08-01 20:10:21
# 14787    delivered      2018-04-17 08:45:43 2018-04-17 08:55:36
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 60289          2018-01-18 19:13:37           2018-01-25 22:10:18
# ...

# %%
delivery_time = orders_df['order_estimated_delivery_date'] - orders_df['order_purchase_timestamp']
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df['delivery_time'] = round(delivery_time/86400)

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 25847  f4925844bd4b0707ded394bc3a93cf5b  3ce5c358d749717eafc34f955b20b652
# 24320  5cee1e12f1ce78f2ded0e50055aaf638  079954fc02a0b0ded54465ecc1f1e6cd
# 49711  61cbfd453bec6d149c4607df0632496f  6eb47ff47e714ed6395a35e258741d99
# 33498  d4720dbbca128b0bf8d6c03b640445cf  b75b00b1545eac25a3eb6831a1cefdac
# 32240  7b2c820a0c74e5a87489ee2463ae2492  7dd7eaca9b852c556a104ef0778b80cc
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 25847    delivered      2018-02-16 11:51:05 2018-02-16 12:07:31
# 24320    delivered      2018-05-20 16:52:56 2018-05-20 17:10:25
# 49711    delivered      2017-10-15 09:40:07 2017-10-16 19:49:27
# 33498    delivered      2017-09-27 22:10:10 2017-09-27 22:24:23
# 32240    delivered      2017-07-05 15:20:45 2017-07-05 17:38:20
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 25847          2018-02-21 19:33:01           2018-02-28 20:09:50
# ...

# %%
orders_df.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %%
orders_df.delivery_time.hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Explore `orders_df` & `customers_df`

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders_customers_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_city
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# Name: order_id, dtype: int64

# %%
orders_customers_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explore `productse_df`

# %%
productse_df.sample(10)
# Out:
#                              product_id    product_category_name  \
# 8318   ca3d7d7b66676d1731e2fe13b5243c43               cool_stuff
# 29724  b296b1ee06b6739f8bc6b1d41d06dbe0                 pet_shop
# 5213   05de46958121361ff78e2a9812db6778         eletrodomesticos
# 11857  7f4b1b38659d1ee551f9bb8f959da24a          cama_mesa_banho
# 14072  636c9bb126460aab67cbbc8a977685d0         moveis_decoracao
# 27945  118c95783c21dc3d1896a9cb46a240ae         moveis_decoracao
# 874    7aeaa8f3e592e380c420e8910a717255         eletrodomesticos
# 28105  442d90d66ceaa3f50027f7430c672820               brinquedos
# 9965   a1efabfd513c691eeb2650e5f04e5cb6            esporte_lazer
# 27804  245d6fd93f56b9e997881f397fbca833  fashion_roupa_masculina
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8318                  39.0                      1514.0                 1.0
# 29724                 56.0                      1496.0                 2.0
# ...

# %%
productse_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32951                 32341
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32341.000000                32341.000000        32341.000000
# ...

# %%
productse_df.groupby(by="product_category_name").agg({
    "product_id": "nunique",
})
# Out:
#                            product_id
# product_category_name
# agro_industria_e_comercio          74
# alimentos                          82
# alimentos_bebidas                 104
# artes                              55
# artes_e_artesanato                 19
# ...                               ...
# sinalizacao_e_seguranca            93
# tablets_impressao_imagem            9
# telefonia                        1134
# telefonia_fixa                    116
# utilidades_domesticas            2335
#
# [73 rows x 1 columns]

# %% [markdown]
# ### Explore `orders_items_df`

# %%
orders_items_df.sample(5)
# Out:
#                                 order_id  order_item_id  \
# 48829   6ef341a08828373038644f3749b9904e              1
# 17582   2850436e0937a8f3408d9b9929a455dc              1
# 80081   b62ced5bbcbad01b30fd58926d727b21              2
# 101952  e75bd2f9adb46257d65d9e916355326a              1
# 15705   23ef69b3ace250bf5783e918620f3919              1
#
#                               product_id                         seller_id  \
# 48829   d88df6347b8ee090e7a79d4493e1abe2  76d64c4aca3a7baf218bf93ef7fa768d
# 17582   d2a05d5e096038f24a2944fe6ddebd29  99a54764c341d5dc80b4a8fac4eba3fb
# 80081   b42c05a477c94b52587fa47d777928df  cfb1a033743668a192316f3c6d1d2671
# 101952  467ee8619a328138b578ace663efbced  004c9cd9d87a3c30c522c48c4fc07416
# 15705   3becff10d1deb92b02f2a1ee62a04524  5b8154610ebb21fb90eb587365e673df
#
#         shipping_limit_date   price  freight_value
# 48829   2018-02-14 07:35:56   37.00          14.10
# 17582   2018-05-07 05:31:13   32.00          15.38
# ...

# %%
orders_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
orders_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
orders_items_df.groupby('order_id').price.sum()
# Out:
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214     58.90
# 00018f77f2f0320c557190d7a144bdd3    239.90
# 000229ec398224ef6ca0657da4fc703e    199.00
# 00024acbcdf0a6daa1e931b038114c75     12.99
# 00042b26cf59d7ce69dfabb4e55b4fd9    199.90
#                                      ...
# fffc94f6ce00a00581880bf54a75a037    299.99
# fffcd46ef2263f404302a634eb57f7eb    350.00
# fffce4705a9662cd70adb13d4a31832d     99.90
# fffe18544ffabc95dfada21779c9644f     55.99
# fffe41c64501cc87c801fd61db3f6244     43.00
# Name: price, Length: 98666, dtype: float64

# %% [markdown]
# ### Explore `orders_items_df` & `productse_df`

# %% [markdown]
# #### Menggabungkan `orders_items_df` & `productse_df`

# %%
orders_items_products_df = pd.merge(
    left=orders_items_df,
    right=productse_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
orders_items_products_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
orders_items_products_df.groupby(by="product_category_name").agg({
    "order_item_id": "nunique",
    "price": "sum"
})
# Out:
#                            order_item_id      price
# product_category_name
# agro_industria_e_comercio              6   72530.47
# alimentos                              6   29393.41
# alimentos_bebidas                      5   15179.48
# artes                                  6   24202.64
# artes_e_artesanato                     2    1814.01
# ...                                  ...        ...
# sinalizacao_e_seguranca                6   21509.23
# tablets_impressao_imagem               2    7528.41
# telefonia                             14  323667.53
# telefonia_fixa                         8   59583.00
# utilidades_domesticas                 12  632248.66
#
# [73 rows x 2 columns]

# %%
orders_items_products_df.groupby(by="product_category_name").agg({
    "order_item_id": "nunique",
    "price": "sum"
}).sort_values(by="price", ascending=False)
# Out:
#                                order_item_id       price
# product_category_name
# beleza_saude                              21  1258681.34
# relogios_presentes                        12  1205005.68
# cama_mesa_banho                           11  1036988.68
# esporte_lazer                              7   988048.97
# informatica_acessorios                    20   911954.32
# ...                                      ...         ...
# flores                                     2     1110.04
# casa_conforto_2                            3      760.27
# cds_dvds_musicais                          2      730.00
# fashion_roupa_infanto_juvenil              1      569.85
# seguros_e_servicos                         1      283.29
#
# [73 rows x 2 columns]

# %% [markdown]
# ### Explore All Data

# %% [markdown]
# #### Menghubungkan semua data

# %%
all_df = pd.merge(
    left=orders_items_products_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
all_df.groupby(by="customer_city").agg({
    "price": "sum"
})
# Out:
#                        price
# customer_city
# abadia dos dourados   358.90
# abadiania             949.99
# abaete               1732.81
# abaetetuba           4028.57
# abaiara               262.90
# ...                      ...
# xinguara             1282.22
# xique-xique           179.79
# zacarias              198.80
# ze doca               688.60
# zortea                 99.80
#
# [4110 rows x 1 columns]

# %%
all_df.groupby(by="customer_state").agg({
    "price": "sum"
})
# Out:
#                      price
# customer_state
# AC                15982.95
# AL                80314.81
# AM                22356.84
# AP                13474.30
# BA               511349.99
# CE               227254.71
# DF               302603.94
# ES               275037.31
# GO               294591.95
# MA               119648.22
# MG              1585308.03
# MS               116812.64
# MT               156453.53
# PA               178947.81
# PB               115268.08
# PE               262788.03
# PI                86914.08
# PR               683083.76
# RJ              1824092.67
# RN                83034.98
# RO                46140.64
# RR                 7829.43
# RS               750304.02
# SC               520553.34
# SE                58920.85
# SP              5202955.05
# TO                49621.74

# %%
all_df.groupby(by="customer_state").agg({
    "price": "sum"
}).sort_values(by="price", ascending=False)
# Out:
#                      price
# customer_state
# SP              5202955.05
# RJ              1824092.67
# MG              1585308.03
# RS               750304.02
# PR               683083.76
# SC               520553.34
# BA               511349.99
# DF               302603.94
# GO               294591.95
# ES               275037.31
# PE               262788.03
# CE               227254.71
# PA               178947.81
# MT               156453.53
# MA               119648.22
# MS               116812.64
# PB               115268.08
# PI                86914.08
# RN                83034.98
# AL                80314.81
# SE                58920.85
# TO                49621.74
# RO                46140.64
# AM                22356.84
# AC                15982.95
# AP                13474.30
# RR                 7829.43

# %%
all_df.to_csv("all_data.csv", index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Bagaimana performa penjualan dan revenue perusahaan dalam beberapa bulan terakhir

# %%
all_df.sample(5)
# Out:
#                                order_id  order_item_id  \
# 1591   03ab852861cd75d0a9225c92a3354a3a              1
# 4608   0a681d622e6b5d09ddfa071a5785c916              1
# 27837  3f5bef65e86c9d1a2c8ff430a74cc202              1
# 1047   026a69b8c98fbfc61de9050c41f1dd95              1
# 18446  2a633b0c6a563a575a8887426a80a53b              2
#
#                              product_id                         seller_id  \
# 1591   374fb6698c278b6af1c7b7c8fb95585e  6560211a19b47992c3666cc44a7e94c0
# 4608   cb03e4f0503f45854e87afe535e0681d  73a63f72308aa20a46f4b1632018f196
# 27837  bc0246e1fa0a21cfceaed952d3e9cd38  c8b0e2b0a7095e5d8219575d5e7e1181
# 1047   629e019a6f298a83aeecc7877964f935  c003204e1ab016dfa150abc119207b24
# 18446  951e2998189b05082eab2080036b135b  ea8482cd71df3c1969d7b9473ff13abc
#
#        shipping_limit_date   price  freight_value product_category_name  \
# 1591   2017-12-14 10:10:25  115.00           8.06    relogios_presentes
# ...

# %%
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
yearly_orders_df = all_df.resample(rule='Y', on='order_purchase_timestamp').agg({
    'order_id': 'nunique',
    'price': 'sum'
})
yearly_orders_df.index = yearly_orders_df.index.strftime('%Y')
yearly_orders_df = yearly_orders_df.reset_index()
yearly_orders_df.rename(columns={
    'order_purchase_timestamp': 'order_date',
    'order_id': 'order_count',
    'price': 'revenue'
}, inplace=True)
yearly_orders_df.head()
# Out:
#   order_date  order_count     revenue
# 0       2016          312    49785.92
# 1       2017        44579  6155806.98
# 2       2018        53775  7386050.80

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    yearly_orders_df['order_date'],
    yearly_orders_df['order_count'],
    marker='o',
    linewidth=2,
    color='#72BCD4'
)
plt.title('Number of Orders per Year', loc='center', fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(
    yearly_orders_df['order_date'],
    yearly_orders_df['revenue'],
    marker='o',
    linewidth=2,
    color='#72BCD4'
)
plt.title('Total Revenue per Year', loc='center', fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### Bagaimana demografi pelanggan yang kita miliki

# %% [markdown]
# #### Berdasarkan negara bagian

# %%
bystate_df = all_df.groupby(by='customer_state').customer_id.nunique().reset_index()
bystate_df.rename(columns={
    'customer_id': 'customer_count'
}, inplace=True)
bystate_df
# Out:
#    customer_state  customer_count
# 0              AC              81
# 1              AL             411
# 2              AM             147
# 3              AP              68
# 4              BA            3358
# 5              CE            1327
# 6              DF            2125
# 7              ES            2025
# 8              GO            2007
# 9              MA             740
# 10             MG           11544
# 11             MS             709
# 12             MT             903
# 13             PA             970
# 14             PB             532
# 15             PE            1648
# 16             PI             493
# 17             PR            4998
# 18             RJ           12762
# 19             RN             482
# 20             RO             247
# 21             RR              46
# 22             RS            5432
# 23             SC            3612
# 24             SE             345
# 25             SP           41375
# ...

# %%
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3",]
sns.barplot(
    x="customer_count",
    y="customer_state",
    data=bystate_df.sort_values(by='customer_count', ascending=False).head(5),
    palette=colors_
)
plt.title("Number of Customer by States", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# C:\Users\PC-HP\AppData\Local\Temp\ipykernel_13812\2203748924.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
bycity_df = all_df.groupby(by='customer_city').customer_id.nunique().reset_index()
bycity_df.rename(columns={
    'customer_id': 'customer_count'
}, inplace=True)
bycity_df
# Out:
#             customer_city  customer_count
# 0     abadia dos dourados               3
# 1               abadiania               1
# 2                  abaete              12
# 3              abaetetuba              11
# 4                 abaiara               2
# ...                   ...             ...
# 4105             xinguara               9
# 4106          xique-xique               3
# 4107             zacarias               2
# 4108              ze doca               5
# 4109               zortea               2
#
# [4110 rows x 2 columns]

# %%
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3",]
sns.barplot(
    x="customer_count",
    y="customer_city",
    data=bycity_df.sort_values(by='customer_count', ascending=False).head(5),
    palette=colors_
)
plt.title("Number of Customer by Cities", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# C:\Users\PC-HP\AppData\Local\Temp\ipykernel_13812\4165081019.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - Conclution pertanyaan 2
